# %%
# initial imports
import pandas as pd
import numpy as np
from path import Path
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Load data
file_path = Path("Resources/winemag-data_cleaned.csv")
wine_df = pd.read_csv(file_path)
wine_df.head()
# Out:
#    points  price  country  designation  province  region_1  variety  winery  \
# 0    96.0  235.0       12           20         6        24        2      15
# 1    96.0  110.0       11           20        26        26        9      15
# 2    96.0   90.0       12           20         6        26       19      15
# 3    96.0   65.0       12           22        27        46       12      15
# 4    95.0   66.0        4           20        31        26        9      15
#
#    tokens  filtered_tokens        1        2        3        4        5  \
# 0      60               36   2701.0  16004.0  23236.0  28401.0  33079.0
# 1      51               31  11481.0  33140.0  41643.0  46758.0  55709.0
# 2      47               30  10077.0  26468.0  32151.0  49402.0  61157.0
# 3      62               43   1546.0   4238.0  13171.0  15324.0  16356.0
# 4      66               37   1546.0  17161.0  18176.0  31536.0  33140.0
#
#          6        7        8         9        10
# 0  39068.0  45330.0  46582.0   63420.0   66669.0
# 1  59455.0  69650.0  79653.0  104662.0  106432.0
# 2  64289.0  76272.0  88398.0   99749.0  119775.0
# 3  25381.0  33140.0  46758.0   56257.0   67144.0
# 4  48479.0  49526.0  65848.0   88378.0   90392.0

# %%
# Data types
wine_df.dtypes
# Out:
# points             float64
# price              float64
# country              int64
# designation          int64
# province             int64
# region_1             int64
# variety              int64
# winery               int64
# tokens               int64
# filtered_tokens      int64
# 1                  float64
# 2                  float64
# 3                  float64
# 4                  float64
# 5                  float64
# 6                  float64
# 7                  float64
# 8                  float64
# 9                  float64
# 10                 float64
# dtype: object

# %%
# find null values
for column in wine_df.columns:
    print(f"Column {column} has {wine_df[column].isnull().sum()} null values")
# Out:
# Column points has 0 null values
# Column price has 0 null values
# Column country has 0 null values
# Column designation has 0 null values
# Column province has 0 null values
# Column region_1 has 0 null values
# Column variety has 0 null values
# Column winery has 0 null values
# Column tokens has 0 null values
# Column filtered_tokens has 0 null values
# Column 1 has 0 null values
# Column 2 has 0 null values
# Column 3 has 0 null values
# Column 4 has 0 null values
# Column 5 has 0 null values
# Column 6 has 0 null values
# Column 7 has 0 null values
# Column 8 has 0 null values
# Column 9 has 0 null values
# Column 10 has 0 null values

# %%
#Transform features
wine_df["1"] = wine_df["1"] / 100
wine_df["2"] = wine_df["2"] / 100
wine_df["3"] = wine_df["3"] / 100
wine_df["4"] = wine_df["4"] / 100
wine_df["5"] = wine_df["5"] / 100
wine_df["6"] = wine_df["6"] / 100
wine_df["7"] = wine_df["7"] / 100
wine_df["8"] = wine_df["8"] / 100
wine_df["9"] = wine_df["9"] / 100
wine_df["10"] = wine_df["10"] / 100
wine_df.head()
# Out:
#    points  price  country  designation  province  region_1  variety  winery  \
# 0    96.0  235.0       12           20         6        24        2      15
# 1    96.0  110.0       11           20        26        26        9      15
# 2    96.0   90.0       12           20         6        26       19      15
# 3    96.0   65.0       12           22        27        46       12      15
# 4    95.0   66.0        4           20        31        26        9      15
#
#    tokens  filtered_tokens       1       2       3       4       5       6  \
# 0      60               36   27.01  160.04  232.36  284.01  330.79  390.68
# 1      51               31  114.81  331.40  416.43  467.58  557.09  594.55
# 2      47               30  100.77  264.68  321.51  494.02  611.57  642.89
# 3      62               43   15.46   42.38  131.71  153.24  163.56  253.81
# 4      66               37   15.46  171.61  181.76  315.36  331.40  484.79
#
#         7       8        9       10
# 0  453.30  465.82   634.20   666.69
# 1  696.50  796.53  1046.62  1064.32
# 2  762.72  883.98   997.49  1197.75
# 3  331.40  467.58   562.57   671.44
# 4  495.26  658.48   883.78   903.92

# %%
wine_df.insert(1, "points_ranked", '')
wine_df.insert(3, "price_ranked", '')
wine_df.head()
# Out:
#    points points_ranked  price price_ranked  country  designation  province  \
# 0    96.0                235.0                    12           20         6
# 1    96.0                110.0                    11           20        26
# 2    96.0                 90.0                    12           20         6
# 3    96.0                 65.0                    12           22        27
# 4    95.0                 66.0                     4           20        31
#
#    region_1  variety  winery  ...       1       2       3       4       5  \
# 0        24        2      15  ...   27.01  160.04  232.36  284.01  330.79
# 1        26        9      15  ...  114.81  331.40  416.43  467.58  557.09
# 2        26       19      15  ...  100.77  264.68  321.51  494.02  611.57
# 3        46       12      15  ...   15.46   42.38  131.71  153.24  163.56
# 4        26        9      15  ...   15.46  171.61  181.76  315.36  331.40
#
#         6       7       8        9       10
# 0  390.68  453.30  465.82   634.20   666.69
# 1  594.55  696.50  796.53  1046.62  1064.32
# 2  642.89  762.72  883.98   997.49  1197.75
# 3  253.81  331.40  467.58   562.57   671.44
# 4  484.79  495.26  658.48   883.78   903.92
#
# [5 rows x 22 columns]

# %%
# points statistics
wine_df['points'].describe()
# Out:
# count    137172.000000
# mean         87.789192
# std           3.220398
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
# price statistics
wine_df['price'].describe()
# Out:
# count    137172.000000
# mean         33.133693
# std          36.327952
# min           4.000000
# 25%          16.000000
# 50%          24.000000
# 75%          40.000000
# max        2300.000000
# Name: price, dtype: float64

# %%
# excellent = 1 = 100-90
# good = 2 = 89.9 - 88
# average = 3 = 87.9 - 86
# ok = 4 = 85.9 - 80

wine_df.loc[(wine_df['points'] >= 90),'points_ranked'] = 1
wine_df.loc[(wine_df['points'] <= 89.9) & (wine_df['points'] >= 88),'points_ranked'] = 2
wine_df.loc[(wine_df['points'] <= 87.9) & (wine_df['points'] >= 86),'points_ranked'] = 3
wine_df.loc[(wine_df['points'] < 85.9),'points_ranked'] = 4
points_ranked_count = wine_df['points_ranked'].value_counts()
print(points_ranked_count)
# Out:
# 1    42439
# 4    33779
# 3    33370
# 2    27584
# Name: points_ranked, dtype: int64

# %%
# top_shelf = 1 = 2300 - 40
# high = 2 = 39.9 - 24
# med = 3 = 23.9 - 16
# low = 4 = 15.9 - 4

wine_df.loc[(wine_df['price'] >= 40),'price_ranked'] = 1
wine_df.loc[(wine_df['price'] <= 39.9) & (wine_df['price'] >= 24),'price_ranked'] = 2
wine_df.loc[(wine_df['price'] <= 23.9) & (wine_df['price'] >= 16),'price_ranked'] = 3
wine_df.loc[(wine_df['price'] < 15.9),'price_ranked'] = 4
price_ranked_count = wine_df['price_ranked'].value_counts()
print(price_ranked_count)
# Out:
# 2    36106
# 1    35322
# 4    33872
# 3    31872
# Name: price_ranked, dtype: int64

# %%
wine_df.tail(20)
# Out:
#         points points_ranked  price price_ranked  country  designation  \
# 137152    90.0             1   65.0            1        4           20
# 137153    89.0             2   52.0            1        4           20
# 137154    89.0             2   38.0            2        4           17
# 137155    87.0             3   37.0            2        4           20
# 137156    94.0             1   30.0            2        4           17
# 137157    94.0             1   25.0            2       12           20
# 137158    93.0             1   30.0            2       12           20
# 137159    93.0             1   65.0            1       12           20
# 137160    92.0             1   30.0            2        4           20
# 137161    92.0             1   38.0            2        4           20
# 137162    91.0             1   37.0            2        4           20
# 137163    91.0             1   19.0            3        6           20
# 137164    91.0             1   38.0            2        4           20
# 137165    91.0             1   30.0            2        4           20
# 137166    91.0             1   70.0            1        4           20
# 137167    91.0             1   20.0            3        6           17
# 137168    91.0             1   27.0            2        4           20
# 137169    91.0             1   20.0            3        6           20
# 137170    90.0             1   52.0            1        4           20
# 137171    90.0             1   15.0            4        6           17
#
#         province  region_1  variety  winery  ...       1       2       3  \
# 137152         5        26       12      15  ...  131.71  145.71  167.04
# 137153         5        26       12      15  ...    4.77   24.37  258.82
# 137154         5        26       12      15  ...   94.92  140.79  334.37
# 137155         5        26       12      15  ...  230.71  258.82  515.55
# 137156        32        26       15      15  ...   57.65  110.76  156.82
# 137157         6         3        9      15  ...   38.90  125.31  151.32
# 137158         6        26       25      15  ...   13.54  122.52  192.12
# 137159         6        24        3      15  ...   55.61  156.82  295.11
# 137160        12        11        3      15  ...    6.14   26.89   89.35
# 137161        12        11        3      15  ...   18.92   82.97  167.49
# 137162        12        11        3      15  ...   35.72  189.11  285.11
# 137163        25        26        3      15  ...   60.78   82.97   94.92
# 137164        12        11        3      15  ...   64.15  250.45  362.96
# 137165        12        11        3      15  ...  131.71  156.82  168.36
# 137166        12        11        3      15  ...   82.97   97.41  180.14
# 137167        35        26       25      15  ...  146.00  618.99  639.25
# 137168        12        11        3      15  ...  156.82  285.11  288.08
# 137169        35        26       25      15  ...   60.34  155.85  160.04
# 137170        12        11        3      15  ...   71.90   82.51  395.29
# 137171        25        26       10      15  ...  136.93  202.83  258.82
#
#              4       5        6        7        8        9       10
# 137152  218.23  259.64   523.51   648.44   706.22   823.72   850.80
# 137153  285.11  336.28   341.21   362.25   424.25   582.33   648.45
# 137154  406.28  452.94   604.17   720.83   734.89   767.64   777.51
# 137155  784.95  997.60   998.92  1071.74  1092.08  1134.32  1180.98
# 137156  209.00  285.11   355.13   363.31   413.59   467.58   661.74
# 137157  326.69  362.96   443.36   467.58   512.47   589.47   617.15
# 137158  243.46  283.28   319.03   333.99   349.96   431.57   467.58
# 137159  318.39  696.50   764.89  1196.42  1196.67  1261.94  1342.72
# 137160  114.57  230.71   248.46   460.95   622.08   895.83  1092.08
# 137161  190.94  397.04   549.39   557.09   679.12   782.69   865.77
# 137162  286.27  313.78   697.72   757.50   866.41  1092.08  1106.20
# 137163  110.76  310.40   467.58   503.49   620.58   696.50   842.21
# 137164  392.39  427.27   620.58   638.48   667.76   755.71   775.06
# 137165  294.24  343.43   368.47   440.16   544.25   593.17   679.12
# 137166  285.11  315.36   460.95   518.62   607.76   654.11   681.72
# 137167  755.71  984.15  1026.82  1136.73  1176.21  1300.37  1417.02
# 137168  397.93  460.95   537.77   813.73   849.47   858.77   866.41
# 137169  246.57  295.53   520.58   696.50   720.18   757.50   941.50
# 137170  438.47  628.07   720.73  1146.10  1159.76  1322.70  1376.44
# 137171  285.11  341.21   561.63   649.00   696.50   720.73   766.18
#
# [20 rows x 22 columns]

# %%
# Define the features set.
X = wine_df.copy()
X = X.drop("points", axis=1)
X = X.drop("points_ranked", axis=1)
X.head()
# Out:
#    price price_ranked  country  designation  province  region_1  variety  \
# 0  235.0            1       12           20         6        24        2
# 1  110.0            1       11           20        26        26        9
# 2   90.0            1       12           20         6        26       19
# 3   65.0            1       12           22        27        46       12
# 4   66.0            1        4           20        31        26        9
#
#    winery  tokens  filtered_tokens       1       2       3       4       5  \
# 0      15      60               36   27.01  160.04  232.36  284.01  330.79
# 1      15      51               31  114.81  331.40  416.43  467.58  557.09
# 2      15      47               30  100.77  264.68  321.51  494.02  611.57
# 3      15      62               43   15.46   42.38  131.71  153.24  163.56
# 4      15      66               37   15.46  171.61  181.76  315.36  331.40
#
#         6       7       8        9       10
# 0  390.68  453.30  465.82   634.20   666.69
# 1  594.55  696.50  796.53  1046.62  1064.32
# 2  642.89  762.72  883.98   997.49  1197.75
# 3  253.81  331.40  467.58   562.57   671.44
# 4  484.79  495.26  658.48   883.78   903.92

# %%
# Define the target set.
y = wine_df["points_ranked"].values
y[:5]
# Out:
# array([1, 1, 1, 1, 1], dtype=object)

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, train_size=0.80)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (109737, 20)
# (27435, 20)
# (109737,)
# (27435,)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Fitting the Decision Tree Model

# %%
y_train = y_train.astype('int')
y_train
# Out:
# array([4, 1, 4, ..., 4, 3, 4])

# %%
# Creating the decision tree classifier instance
model = tree.DecisionTreeClassifier()

# %%
# Fitting the model
model = model.fit(X_train_scaled, y_train)

# %%
print(model)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Making Predictions Using the Tree Model

# %%
# Making predictions using the testing data
predictions = model.predict(X_test_scaled)

# %% [markdown]
# ### Model Evaluation

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 1", "Actual 2", "Actual 3", "Actual 4"], columns=["Predicted 1", "Predicted 2", "Predicted 3", "Predicted 4"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-cbc34b0d8c3b> in <module>
#       1 # Calculating the confusion matrix
# ----> 2 cm = confusion_matrix(y_test, predictions)
#       3 cm_df = pd.DataFrame(
#       4     cm, index=["Actual 1", "Actual 2", "Actual 3", "Actual 4"], columns=["Predicted 1", "Predicted 2", "Predicted 3", "Predicted 4"]
#       5 )
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     294
#     295     """
# --> 296     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     297     if y_type not in ("binary", "multiclass"):
#     298         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      91     if len(y_type) > 1:
#      92         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 93                          "and {1} targets".format(type_true, type_pred))
#      94
#      95     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of unknown and multiclass targets

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
